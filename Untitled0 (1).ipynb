# %%
a=20
type(a)
# Out:
# int

# %%
a=2.1
type(a)
# Out:
# float

# %%
a=2.5+1.5j
type(a)
# Out:
# complex

# %%
a.real
# Out:
# 2.5

# %%
a.imag
# Out:
# 1.5

# %%
test=(3>4)
type(test)
# Out:
# bool

# %%
test
# Out:
# False

# %% [markdown]
# 7/2

# %%
1+3
# Out:
# 4

# %%
3*4
# Out:
# 12

# %%
8-2
# Out:
# 6

# %%
colors=['red','blue','green','black']
type(colors)
# Out:
# list

# %%
colors[1:2]
# Out:
# ['blue']

# %%
colors[3]
# Out:
# 'black'

# %%
colors[-2]
# Out:
# 'green'
